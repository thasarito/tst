# %%
import json

# %%
f = open('endata.json', encoding='utf-8')

# %%
js = json.loads(f.read())

# %%
js
# Out:
# [{'word': 'กระต่ายป่า',
#   'readas': 'กระ-ต่าย-ป่า',
#   'meaning': 'เป็นศัพท์ที่ใช้ในวงการกระเทย หมายถึง ผู้ชายที่ดูซื่อๆ ไม่รู้เรื่องอะไรมากนัก   เช่น  "พวกกระต่ายป่านี่น่ารักจริงๆเลยนะ ดูใสซื่อ น่ารัก น่าฟัดจัง"',
#   'url': 'https://dictionary.sanook.com/search/dict-slang/กระต่ายป่า'},
#  {'word': 'กั๊ก',
#   'readas': 'กั๊ก',
#   'meaning': 'หมายถึง ไม่อยากเลือก หรือเก็บเอาไว้เผื่อเลือก',
#   'url': 'https://dictionary.sanook.com/search/dict-slang/กั๊ก'},
#  {'word': 'กิ๊ก',
#   'readas': 'กิ๊ก',
#   'meaning': 'กิ๊ก หมายถึง บุคคลที่มีความสัมพันธ์อย่างคู่รัก แต่ไม่ใช่คู่รัก',
#   'url': 'https://dictionary.sanook.com/search/dict-slang/กิ๊ก'},
#  {'word': 'กิ๊บกั๊บ',
#   'readas': 'กิ๊บ-กั๊บ',
#   'meaning': 'กิ๊บกั๊บ เป็นคำที่ใช้เรียกคน - บุคคล ถ้าเขาผู้นั้น มีกริยา ท่าทางที่ผิดแผกไปจาก ส่งที่ควรจะเป็น แต่ต้องสร้างสรรค์ เช่น เขาผู้นั้น แต่งตัวทั้งชุดเข้ากันมาก สีดำเท่ห์ สง่า ทั้งตัว แต่ เดินกับเพื่อน 5 คนที่ เพื่อนๆใส่เสื้อโทน ขาว เรียกบุคคล คนนั้นว่า เขา กิ๊บกั๊บ มาก',
# ...
